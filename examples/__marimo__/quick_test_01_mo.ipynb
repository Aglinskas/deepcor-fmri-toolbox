# %%
import os
from matplotlib import pyplot as plt

# %%
a = 'hello'
a

# %%
plt.plot([1,2,3,4])

# %%
import numpy as np
x = np.linspace(-3, 3, 100)
y = x ** 2
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("U-shaped curve")
ax.set_xlabel("x")
ax.set_ylabel("y")
fig
